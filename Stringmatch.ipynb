# %%
with open("python_assesment.csv","r") as f:
    names=f.read().split("\n")

# %%
names
# Out:
# [',name',
#  '0,GOPI NON FAT  YOGURT',
#  '1,HIMALAYA TULSI RESPIRATORY WELLNESS',
#  '2,DEEP POTATOES DICED',
#  '3,BIKAJI GUR REWARI',
#  '4,BAROODY MAAMOUL DATE FILLED COOKIES',
#  '5,CLOROX',
#  '6,BURMANS YELLOW MUSTARD',
#  '7,BABY GOAT CLEAN HALAL',
#  '8,EXQUISITAS BAKERY PEPERECHAS',
#  '9,EMAMI FAIR AND HANDSOME',
#  '10,BHAVANI MADRAS JAGGERY CUBES',
#  '11,GULLON NO SUGAR TWINS CREME',
#  '12,ATTICA KALAMATA OLIVES PITTED',
#  '13,HEINZ BEANS WITH TOMATO SAUSE',
#  '14,COBAN KASAP SUCUGU',
#  '15,BANQUET POPCORN CHICKEN',
#  '16,KCB PUNJABI VEG BISCUIT',
#  '17,KOSKA TAHIN HELVA PISTACHIO',
#  '18,COUSCUS',
#  '19,HAITHI MANGO',
#  '20,AFGANI FIG',
#  '21,ELEGANT PEELER',
#  '22,GOAT LIVER',
#  '23,BLACK CURRANT',
#  '24,KANGNA HERBAL HENNA',
#  '25,BARILLA THIN SPAGHETTI',
#  '26,FUJI APPLE',
#  '27,GRAPE SEED OIL',
#  '28,KOSKA TAHIN HELVA SADE PLAIN',
#  '29,DETTOL ANTI BAKTERI COOL SOAP',
#  '30,CASTELLA ALL SPICED GROUND',
#  '31,LUCKY COOKED SHRIMP TAIL 71/90',
# ...

# %%
from fuzzywuzzy import process

# %%
def get_matches(query,choices,limit=3):
    results=process.extract(query,choices,limit=limit)
    return results

# %%
get_matches("CHIC",names)
# Out:
# [('15,BANQUET POPCORN CHICKEN', 90),
#  ('61,CHICKEN BREAST CUBES', 90),
#  ('186,CHICKEN FINGERS STRIP', 90)]
